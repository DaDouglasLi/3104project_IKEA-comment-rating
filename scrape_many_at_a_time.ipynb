# %%
import requests
import json
import time
import csv
import copy

LOCALE = "en"
MARKET = "us" #not used here

# http headers copied from browser DevTools
COMMON_HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Origin": "https://www.ikea.com",
    "Referer": "https://www.ikea.com/",
    "x-client-id": "a1047798-0fc4-446e-9616-0afe3256d0d7", #change when no longer avaliable
}

# modified from request payload from browser DevTools
BASE_PAYLOAD = {
    "filter": {
        "and": [
            {"field": "sourceLangCode", "value": "en"},
        ],
        "not": [],
    },
    "sort": [
        {"field": "submissionOn", "direction": "desc"},
    ],
    "page": {"size": 20, "number": 1},
}


def fetch_all_reviews(product_id, market=MARKET, locale=LOCALE):
    # construct url
    rating_url = f"https://web-api.ikea.com/tugc/public/v5/rating/{market}/{locale}/{product_id}"
    reviews_url = f"https://web-api.ikea.com/tugc/public/v5/reviews/{market}/{locale}/{product_id}"

    session = requests.Session()

    print(f"product_id={product_id}")
    # first send GET request for each product
    r = session.get(rating_url, headers=COMMON_HEADERS)
    print("GET rating status:", r.status_code)

    all_reviews = []
    # scrap reviews page by page
    page_size = BASE_PAYLOAD["page"]["size"]
    page_number = 1

    while True:
        payload = copy.deepcopy(BASE_PAYLOAD)
        payload["page"]["number"] = page_number
        headers = COMMON_HEADERS.copy()
        headers["Content-Type"] = "application/json"

        print(f"\nFetching product {product_id} page {page_number} ...")
        # send POST request
        resp = session.post(reviews_url, headers=headers, json=payload)
        print("POST status:", resp.status_code)
        
        # ensure code is 200
        if resp.status_code != 200:
            print("Body:", resp.text[:500])
            break
        # parse json
        data = resp.json()
        print("Type of data:", type(data))
        
        # in case it is a list
        if isinstance(data, list):
            reviews = data
        else:
            print("Top-level keys (dict):", list(data.keys()))
            reviews = (
                data.get("data")
                or data.get("reviews")
                or data.get("items")
                or []
            )

        if page_number == 1 and reviews:
            print("Sample review:", json.dumps(reviews[0], ensure_ascii=False, indent=2))

        if not reviews:
            print("No more reviews, stop.")
            break

        # add product id for each review
        for r in reviews:
            r["productId"] = product_id

        all_reviews.extend(reviews)
        print(f"Got {len(reviews)} reviews, total {len(all_reviews)}")
        
        # reaching end of reviews
        if len(reviews) < page_size:
            print("Last page reached.")
            break

        page_number += 1
        time.sleep(0.5)

    return all_reviews

# %%
def save_to_csv(reviews, filename="ikea_reviews_multi.csv"):
    if not reviews:
        print("no reviews got")
        return

    print("First review keys:", reviews[0].keys())

    fields = [
        'productId',
        'itemKey', 'id', 'type', 'sourceCountryCode', 'sourceLangCode',
        'title', 'text', 'primaryRating', 'secondaryRatings', 'isRecommended',
        'verifiedPurchase', 'verifiedReviewer', 'anonymousReviewer',
        'positiveFeedbacksCount', 'negativeFeedbacksCount', 'submissionOn',
        'response', 'hasMedia', 'medias', 'reviewer', 'updatedOn'
    ]
    
    # store as csv
    with open(filename, "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.writer(f)
        writer.writerow(fields)
        for r in reviews:
            row = [r.get(k, "") for k in fields]
            writer.writerow(row)

    print(f"Saved {len(reviews)} reviews to {filename}")

# %%
if __name__ == "__main__":
    PRODUCT_IDS = [
        "70511903",#VESTERÖY Pocket spring mattress, medium firm/white, Twin
        "50511857",#VALEVÅG Pocket spring mattress, medium firm/white, Queen
        "30511877",#VÅGSTRANDA Pocket spring mattress, medium firm/white, Queen
        "60511913",#ÅNNELAND Hybrid mattress, firm/white, Queen
        "80348520",#KRUMMELUR Foam mattress for crib, 27 1/2x52
        # some of the mattresses with higest amount of visable reviews
    ]

    all_reviews = []

    for pid in PRODUCT_IDS:
        reviews = fetch_all_reviews(pid)
        print(f"Product {pid} fetched {len(reviews)} reviews")
        all_reviews.extend(reviews)

    print("\nTotal fetched for all products:", len(all_reviews))
    if all_reviews:
        save_to_csv(all_reviews)
    else:
        print("No reviews fetched for any product.")
# Out:
# === 预热 session, product_id=70511903 ===
# GET rating status: 200
#
# Fetching product 70511903 page 1 ...
# POST status: 200
# Type of data: <class 'list'>
# Sample review: {
#   "itemKey": {
#     "itemNo": "00511906",
#     "itemType": "art",
#     "sourceItemNo": "00511906"
#   },
#   "id": "2463ad58-7811-4f29-8387-127fd3d13954",
#   "type": "web-profile",
#   "sourceCountryCode": "ca",
#   "sourceLangCode": "en",
#   "title": "not for Malm bedframe",
#   "text": "this mattress is too low for the Malm bed frame",
#   "primaryRating": {
#     "ratingRange": 5,
#     "ratingValue": 1
#   },
#   "secondaryRatings": null,
#   "isRecommended": false,
#   "verifiedPurchase": true,
#   "verifiedReviewer": false,
#   "anonymousReviewer": false,
#   "positiveFeedbacksCount": 0,
#   "negativeFeedbacksCount": 0,
#   "submissionOn": "2025-11-10T17:18:23Z",
#   "response": {
#     "text": "Thank you for your review. We are sorry that this product did not meet your expectations. We will be sure to forward your comments to the appropriate department for evaluation.-YS",
#     "responseBy": "IKEA CA",
#     "responseOn": "2025-11-10T17:22:34Z",
#     "type": "public"
#   },
#   "hasMedia": false,
#   "medias": null,
#   "reviewer": {
#     "displayName": "Jennifer"
#   },
#   "updatedOn": "2025-11-10T17:22:35Z"
# }
# Got 20 reviews, total 20
#
# Fetching product 70511903 page 2 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 40
#
# Fetching product 70511903 page 3 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 60
#
# Fetching product 70511903 page 4 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 80
#
# Fetching product 70511903 page 5 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 100
#
# Fetching product 70511903 page 6 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 120
#
# Fetching product 70511903 page 7 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 140
#
# Fetching product 70511903 page 8 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 160
#
# Fetching product 70511903 page 9 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 180
#
# Fetching product 70511903 page 10 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 200
#
# Fetching product 70511903 page 11 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 220
#
# Fetching product 70511903 page 12 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 240
#
# Fetching product 70511903 page 13 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 260
#
# Fetching product 70511903 page 14 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 280
#
# Fetching product 70511903 page 15 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 300
#
# Fetching product 70511903 page 16 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 320
#
# Fetching product 70511903 page 17 ...
# POST status: 200
# Type of data: <class 'list'>
# No more reviews, stop.
# Product 70511903 fetched 320 reviews
#
# === 预热 session, product_id=50511857 ===
# GET rating status: 200
#
# Fetching product 50511857 page 1 ...
# POST status: 200
# Type of data: <class 'list'>
# Sample review: {
#   "itemKey": {
#     "itemNo": "30511863",
#     "itemType": "art",
#     "sourceItemNo": "30511863"
#   },
#   "id": "98d4b72d-e024-428f-b511-62e4e1a284ea",
#   "type": "web",
#   "sourceCountryCode": "ca",
#   "sourceLangCode": "en",
#   "title": "Stop calling it firm!",
#   "text": "This mattress is NOT firm. I used the comfort guide to choose it, but it has contributed to severe lower back pain and appears to be sagging already in the middle. Pity that I am past the 90d mark or else I'd just return it.",
#   "primaryRating": {
#     "ratingRange": 5,
#     "ratingValue": 1
#   },
#   "secondaryRatings": null,
#   "isRecommended": false,
#   "verifiedPurchase": false,
#   "verifiedReviewer": true,
#   "anonymousReviewer": false,
#   "positiveFeedbacksCount": 0,
#   "negativeFeedbacksCount": 0,
#   "submissionOn": "2025-11-11T23:49:06Z",
#   "response": {
#     "text": "Hi, we're truly sorry to hear about your disappointment with our product. We appreciate your feedback and will work to improve the quality and value for our customers. Thank you for bringing this to our attention. -YS",
#     "responseBy": "IKEA CA",
#     "responseOn": "2025-11-12T16:14:14Z",
#     "type": "public"
#   },
#   "hasMedia": false,
#   "medias": null,
#   "reviewer": {
#     "displayName": "Londa"
#   },
#   "updatedOn": "2025-11-12T16:14:15Z"
# }
# Got 20 reviews, total 20
#
# Fetching product 50511857 page 2 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 40
#
# Fetching product 50511857 page 3 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 60
#
# Fetching product 50511857 page 4 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 80
#
# Fetching product 50511857 page 5 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 100
#
# Fetching product 50511857 page 6 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 120
#
# Fetching product 50511857 page 7 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 140
#
# Fetching product 50511857 page 8 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 160
#
# Fetching product 50511857 page 9 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 180
#
# Fetching product 50511857 page 10 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 200
#
# Fetching product 50511857 page 11 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 220
#
# Fetching product 50511857 page 12 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 240
#
# Fetching product 50511857 page 13 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 260
#
# Fetching product 50511857 page 14 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 280
#
# Fetching product 50511857 page 15 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 300
#
# Fetching product 50511857 page 16 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 320
#
# Fetching product 50511857 page 17 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 340
#
# Fetching product 50511857 page 18 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 360
#
# Fetching product 50511857 page 19 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 380
#
# Fetching product 50511857 page 20 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 400
#
# Fetching product 50511857 page 21 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 420
#
# Fetching product 50511857 page 22 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 440
#
# Fetching product 50511857 page 23 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 460
#
# Fetching product 50511857 page 24 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 16 reviews, total 476
# Last page reached.
# Product 50511857 fetched 476 reviews
#
# === 预热 session, product_id=30511877 ===
# GET rating status: 200
#
# Fetching product 30511877 page 1 ...
# POST status: 200
# Type of data: <class 'list'>
# Sample review: {
#   "itemKey": {
#     "itemNo": "00511874",
#     "itemType": "art",
#     "sourceItemNo": "00511874"
#   },
#   "id": "eaaa2946-e225-4999-bea2-cb3bf15e1704",
#   "type": "app",
#   "sourceCountryCode": "ca",
#   "sourceLangCode": "en",
#   "title": "Terrible ",
#   "text": "Worst purchase ever and fighting to get a return this matrix complètement before soft after 6 month it’s impossible to sleep on it anymore ",
#   "primaryRating": {
#     "ratingRange": 5,
#     "ratingValue": 1
#   },
#   "secondaryRatings": [
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "appearance",
#       "label": "Appearance"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "product_quality",
#       "label": "Product quality"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "value_for_money",
#       "label": "Value for money"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "works_as_expected",
#       "label": "Works as expected"
#     }
#   ],
#   "isRecommended": false,
#   "verifiedPurchase": false,
#   "verifiedReviewer": true,
#   "anonymousReviewer": false,
#   "positiveFeedbacksCount": 0,
#   "negativeFeedbacksCount": 0,
#   "submissionOn": "2025-11-08T19:00:43Z",
#   "response": {
#     "text": "Hej! We’re sorry to hear your mattress hasn’t met your expectations for comfort and support. It can take some time for you and your new mattress to get used to each other, which is why we offer our ‘Love it or exchange it’ 90-day trial policy for newly purchased mattresses. If, after trying it for a while, you still find it too firm or too soft, you can exchange it for another model. Keep in mind that your sales receipt is required. Tack! -Lu",
#     "responseBy": "IKEA CA",
#     "responseOn": "2025-11-09T17:17:41Z",
#     "type": "public"
#   },
#   "hasMedia": false,
#   "medias": null,
#   "reviewer": {
#     "displayName": "Francois"
#   },
#   "updatedOn": "2025-11-09T17:17:42Z"
# }
# Got 20 reviews, total 20
#
# Fetching product 30511877 page 2 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 40
#
# Fetching product 30511877 page 3 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 60
#
# Fetching product 30511877 page 4 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 80
#
# Fetching product 30511877 page 5 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 100
#
# Fetching product 30511877 page 6 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 120
#
# Fetching product 30511877 page 7 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 140
#
# Fetching product 30511877 page 8 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 160
#
# Fetching product 30511877 page 9 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 180
#
# Fetching product 30511877 page 10 ...
# POST status: 200
# Type of data: <class 'list'>
# No more reviews, stop.
# Product 30511877 fetched 180 reviews
#
# === 预热 session, product_id=60511913 ===
# GET rating status: 200
#
# Fetching product 60511913 page 1 ...
# POST status: 200
# Type of data: <class 'list'>
# Sample review: {
#   "itemKey": {
#     "itemNo": "10481744",
#     "itemType": "art",
#     "sourceItemNo": "10481744"
#   },
#   "id": "24aa5a06-5add-4100-ac6b-12b201908af2",
#   "type": "email",
#   "sourceCountryCode": "us",
#   "sourceLangCode": "en",
#   "title": "Poor craftmanship",
#   "text": "We were looking for a hybrid mattress. This one was so uncomfortable. We could feel every spring and it was poking our back and sides. It is also a very thin mattress. We have a slat bed and it barely stick out of the side of the frame. The delivery and return process is also poor and inconvenient.",
#   "primaryRating": {
#     "ratingRange": 5,
#     "ratingValue": 1
#   },
#   "secondaryRatings": [
#     {
#       "ratingRange": 5,
#       "ratingValue": 3,
#       "id": "appearance",
#       "label": "Appearance"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "product_quality",
#       "label": "Product quality"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "value_for_money",
#       "label": "Value for money"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 1,
#       "id": "works_as_expected",
#       "label": "Works as expected"
#     }
#   ],
#   "isRecommended": false,
#   "verifiedPurchase": true,
#   "verifiedReviewer": false,
#   "anonymousReviewer": false,
#   "positiveFeedbacksCount": 4,
#   "negativeFeedbacksCount": 0,
#   "submissionOn": "2025-11-06T19:37:30Z",
#   "response": {
#     "text": "Hej! We understand it can be frustrating when something you've purchased doesn't meet your expectations. We’re constantly learning that we can do more to renew and improve, and your feedback helps us make these changes.",
#     "responseBy": "IKEA US",
#     "responseOn": "2025-11-07T14:42:48Z",
#     "type": "public"
#   },
#   "hasMedia": false,
#   "medias": null,
#   "reviewer": {
#     "displayName": "Christina"
#   },
#   "updatedOn": "2025-11-11T22:23:43Z"
# }
# Got 20 reviews, total 20
#
# Fetching product 60511913 page 2 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 40
#
# Fetching product 60511913 page 3 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 60
#
# Fetching product 60511913 page 4 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 80
#
# Fetching product 60511913 page 5 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 100
#
# Fetching product 60511913 page 6 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 120
#
# Fetching product 60511913 page 7 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 20 reviews, total 140
#
# Fetching product 60511913 page 8 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 10 reviews, total 150
# Last page reached.
# Product 60511913 fetched 150 reviews
#
# === 预热 session, product_id=80348520 ===
# GET rating status: 200
#
# Fetching product 80348520 page 1 ...
# POST status: 200
# Type of data: <class 'list'>
# Sample review: {
#   "itemKey": {
#     "itemNo": "00348519",
#     "itemType": "art",
#     "sourceItemNo": "00348519"
#   },
#   "id": "15c557f4-a4d1-43c8-ba49-b3e7c161e902",
#   "type": "email",
#   "sourceCountryCode": "ca",
#   "sourceLangCode": "en",
#   "title": "Good quality",
#   "text": "The thicker mattress (this one) is much better for the crib we used it on.",
#   "primaryRating": {
#     "ratingRange": 5,
#     "ratingValue": 4
#   },
#   "secondaryRatings": [
#     {
#       "ratingRange": 5,
#       "ratingValue": 4,
#       "id": "appearance",
#       "label": "Appearance"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 5,
#       "id": "product_quality",
#       "label": "Product quality"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 4,
#       "id": "value_for_money",
#       "label": "Value for money"
#     },
#     {
#       "ratingRange": 5,
#       "ratingValue": 5,
#       "id": "works_as_expected",
#       "label": "Works as expected"
#     }
#   ],
#   "isRecommended": null,
#   "verifiedPurchase": true,
#   "verifiedReviewer": false,
#   "anonymousReviewer": false,
#   "positiveFeedbacksCount": 0,
#   "negativeFeedbacksCount": 0,
#   "submissionOn": "2025-08-29T16:38:35Z",
#   "response": {
#     "text": "Hello Don! We're delighted to hear that the mattress worked well for your crib. Tack! -Lu",
#     "responseBy": "IKEA CA",
#     "responseOn": "2025-10-06T22:30:28Z",
#     "type": "public"
#   },
#   "hasMedia": false,
#   "medias": null,
#   "reviewer": {
#     "displayName": "Anonymous"
#   },
#   "updatedOn": "2025-10-06T22:30:28Z"
# }
# Got 20 reviews, total 20
#
# Fetching product 80348520 page 2 ...
# POST status: 200
# Type of data: <class 'list'>
# Got 10 reviews, total 30
# Last page reached.
# Product 80348520 fetched 30 reviews
#
# Total fetched for all products: 1156
# First review keys: dict_keys(['itemKey', 'id', 'type', 'sourceCountryCode', 'sourceLangCode', 'title', 'text', 'primaryRating', 'secondaryRatings', 'isRecommended', 'verifiedPurchase', 'verifiedReviewer', 'anonymousReviewer', 'positiveFeedbacksCount', 'negativeFeedbacksCount', 'submissionOn', 'response', 'hasMedia', 'medias', 'reviewer', 'updatedOn', 'productId'])
# Saved 1156 reviews to ikea_reviews_multi.csv
